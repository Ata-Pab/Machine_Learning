# %%
# Get electron microscopy dataset (https://www.epfl.ch/labs/cvlab/data/data-em/)
# !wget https://documents.epfl.ch/groups/c/cv/cvlab-unit/www/data/%20ElectronMicroscopy_Hippocampus/volumedata.tif

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Get custom packages from Github

# %%
import os

os.makedirs('utils/', exist_ok=True)
os.chdir('utils')

! wget https://raw.githubusercontent.com/Ata-Pab/Machine_Learning/master/utils/models.py
! wget https://raw.githubusercontent.com/Ata-Pab/Machine_Learning/master/utils/losses.py
! wget https://raw.githubusercontent.com/Ata-Pab/Machine_Learning/master/utils/vision.py
! wget https://raw.githubusercontent.com/Ata-Pab/Machine_Learning/master/utils/callbacks.py
! wget https://raw.githubusercontent.com/Ata-Pab/Machine_Learning/master/utils/utils.py

os.chdir('/content')
print("Current working directory", os.getcwd())
# Out:
# --2023-10-30 08:19:23--  https://raw.githubusercontent.com/Ata-Pab/Machine_Learning/master/utils/models.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15061 (15K) [text/plain]
# Saving to: ‘models.py’
#
# models.py           100%[===================>]  14.71K  --.-KB/s    in 0.001s
#
# 2023-10-30 08:19:24 (19.5 MB/s) - ‘models.py’ saved [15061/15061]
#
# --2023-10-30 08:19:24--  https://raw.githubusercontent.com/Ata-Pab/Machine_Learning/master/utils/losses.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5722 (5.6K) [text/plain]
# Saving to: ‘losses.py’
#
# losses.py           100%[===================>]   5.59K  --.-KB/s    in 0s
#
# 2023-10-30 08:19:24 (83.8 MB/s) - ‘losses.py’ saved [5722/5722]
#
# --2023-10-30 08:19:24--  https://raw.githubusercontent.com/Ata-Pab/Machine_Learning/master/utils/vision.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12205 (12K) [text/plain]
# Saving to: ‘vision.py’
#
# vision.py           100%[===================>]  11.92K  --.-KB/s    in 0s
#
# 2023-10-30 08:19:24 (68.4 MB/s) - ‘vision.py’ saved [12205/12205]
#
# --2023-10-30 08:19:24--  https://raw.githubusercontent.com/Ata-Pab/Machine_Learning/master/utils/callbacks.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9733 (9.5K) [text/plain]
# Saving to: ‘callbacks.py’
#
# callbacks.py        100%[===================>]   9.50K  --.-KB/s    in 0s
#
# 2023-10-30 08:19:24 (118 MB/s) - ‘callbacks.py’ saved [9733/9733]
#
# --2023-10-30 08:19:24--  https://raw.githubusercontent.com/Ata-Pab/Machine_Learning/master/utils/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18100 (18K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]  17.68K  --.-KB/s    in 0.001s
#
# 2023-10-30 08:19:25 (21.1 MB/s) - ‘utils.py’ saved [18100/18100]
#
# Current working directory /content

# %%
from utils.losses import dice_coef, jacard_coef, jacard_coef_loss, dice_coef_loss
from utils.models import UNet, Attention_UNet, Attention_ResUNet
from utils import utils
from utils import vision

# %%
! pip install -q kaggle

#from google.colab import files
# files.upload()

! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download -d andrewmvd/cancer-instance-segmentation-and-classification-2
# Out:
# Downloading cancer-instance-segmentation-and-classification-2.zip to /content
#  97% 673M/697M [00:05<00:00, 95.3MB/s]
# 100% 697M/697M [00:06<00:00, 120MB/s]

# %%
utils.unzip_data('/content/cancer-instance-segmentation-and-classification-2.zip')

# %%
IMGS_PATH = '/content/Images/images.npy'
MASKS_PATH = '/content/Masks/masks.npy'

# %%
img_array = np.load(IMGS_PATH, mmap_mode='r')
mask_array = np.load(MASKS_PATH, mmap_mode='r')

# %%
print("Number of images: ", len(img_array))
print("Number of masks: ", len(mask_array))
# Out:
# Number of images:  2523
# Number of masks:  2523

# %%
from sklearn.model_selection import train_test_split

# Use only first 600 images due to memory overflow
X_train, X_test, y_train, y_test = train_test_split(img_array[:600], mask_array[:600], test_size = 0.10, random_state = 0)

# %%
def visualize_mask_data(dataset, ix):
  #fig = plt.figure(figsize=(10, 10))

  for index in range(y_train.shape[-1]):
      plt.subplot(2, 3, index + 1)
      plt.imshow(dataset[ix, :, :, (index-1)])
      plt.axis('off')

  plt.show()

# %%
visualize_mask_data(y_train, 0)

# %%
visualize_mask_data(y_train, 1)

# %% [markdown]
# We will only use first (0) channel masks for binary mask creation

# %%
plt.imshow(y_train[0,:,:,0])

# %%
y_train = y_train[:,:,:,0]  # Mask array shape (60, 256, 256, 6), convert it to the (60, 256, 256, 1)
y_train = tf.expand_dims(y_train, axis=-1)
y_test = y_test[:,:,:,0]  # Mask array shape (60, 256, 256, 6), convert it to the (60, 256, 256, 1)
y_test = tf.expand_dims(y_test, axis=-1)

print("X_train.shape: ", X_train.shape)
print("X_test.shape: ", X_test.shape)
print("y_train.shape: ", y_train.shape)
print("y_test.shape: ", y_test.shape)
# Out:
# X_train.shape:  (540, 256, 256, 3)
# X_test.shape:  (60, 256, 256, 3)
# y_train.shape:  (540, 256, 256, 1)
# y_test.shape:  (60, 256, 256, 1)

# %%
print(f'X_train min: {np.min(X_train)}, X_train max: {np.max(X_train)}, X_test min: {np.min(X_test)}, X_test max: {np.max(X_test)}')
print(f'y_train min: {np.min(y_train)}, y_train max: {np.max(y_train)}, y_test min: {np.min(y_test)}, y_test max: {np.max(y_test)}')
# Out:
# X_train min: 0.0, X_train max: 255.0, X_test min: 0.0, X_test max: 255.0
# y_train min: 0.0, y_train max: 479.0, y_test min: 0.0, y_test max: 378.0

# %% [markdown]
# We need to normalize/scale Mask images into [0,1]

# %%
normalize = lambda x: (x-np.min(x))/(np.max(x)-np.min(x))

y_train = normalize(y_train)
y_test = normalize(y_test)

print(f'y_train min: {np.min(y_train)}, y_train max: {np.max(y_train)}, y_test min: {np.min(y_test)}, y_test max: {np.max(y_test)}')
# Out:
# y_train min: 0.0, y_train max: 1.0, y_test min: 0.0, y_test max: 1.0

# %% [markdown]
# Normalize train and test images

# %%
X_train = normalize(X_train)
X_test = normalize(X_test)

print(f'X_train min: {np.min(X_train)}, X_train max: {np.max(X_train)}, X_test min: {np.min(X_test)}, X_test max: {np.max(X_test)}')
# Out:
# X_train min: 0.0, X_train max: 1.0, X_test min: 0.0, X_test max: 1.0

# %% [markdown]
# Convert RGB mask images to binary mask images

# %%
def rgb_to_gray(images):
  return np.dot(images[..., :3], [0.299, 0.587, 0.114])

# %%
def convert_rgb_to_binary_mask(images):
  #images = tf.image.rgb_to_grayscale(images).numpy()  # or use rgb_to_gray(images)
  if type(images) != np.ndarray:
    images = images.numpy()
  images[images > 0.0] = 1.0
  return images > 0.0

# %%
y_train = convert_rgb_to_binary_mask(y_train)
y_test = convert_rgb_to_binary_mask(y_test)

# %%
for ix, image in enumerate(y_train[:6]):
    plt.subplot(2, 3, ix + 1)
    plt.imshow(image[:, :, 0], cmap='gray')
    plt.axis('off')

plt.show()

# %%
INPUT_SHAPE = (256, 256, 3)
NUM_LABELS = 1  #Binary
BATCH_SIZE = 8
EPOCHS = 50

FILTER_NUM = 64   # number of filters for the conv layer
FILTER_SIZE = 3   # size of the convolutional filter (3,3)
UP_SAMP_SIZE = 2  # size of upsampling filters

# %%
def create_dataset_pipeline(tensor, batch_size, shuffle=False):
    # Read images from directory and reshape, scale
    dataset = tf.data.Dataset.from_tensor_slices(tensor)

    # Shuffle (only training set) and create batches
    if shuffle == True:
        dataset = dataset.shuffle(len(tensor))
    dataset = dataset.batch(batch_size)
    dataset = dataset.cache()
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)

    return dataset

# %%
X_train_data = create_dataset_pipeline(X_train, BATCH_SIZE)
X_test_data = create_dataset_pipeline(X_test, BATCH_SIZE)
y_train_data = create_dataset_pipeline(y_train, BATCH_SIZE)
y_test_data = create_dataset_pipeline(y_test, BATCH_SIZE)

# %%
print(f"Batch Size: {BATCH_SIZE}")
print(f"Number of X_train_data batches: {len(X_train_data)}")
print(f"Number of X_test_data batches: {len(X_test_data)}")
print(f"Number of y_train_data batches: {len(y_train_data)}")
print(f"Number of y_test_data batches: {len(y_test_data)}")
# Out:
# Batch Size: 8
# Number of X_train_data batches: 68
# Number of X_test_data batches: 8
# Number of y_train_data batches: 68
# Number of y_test_data batches: 8

# %%
vision.show_image_samples_from_batch(X_train_data, grid=(3,3))

# %% [markdown]
# ### Training U-Net Model

# %%
att_unet_model = Attention_UNet(input_shape=INPUT_SHAPE, filter_size=FILTER_SIZE, filter_num=FILTER_NUM, up_sample_size=UP_SAMP_SIZE, num_classes=NUM_LABELS, verbose=1)
# Out:
# Model: "Attention_UNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 256, 256, 64)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 64)         36928     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 64)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)        73856     ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128, 128, 128)        512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 128, 128, 128)        0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 128)        147584    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 128)        512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 128)        0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 128)          0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 256)          1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 256)          590080    ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 64, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 256)          0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 512)          2048      ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 512)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 512)          2359808   ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 512)          2048      ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 512)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 512)          0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 1024)         4719616   ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 16, 16, 1024)         4096      ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 16, 16, 1024)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 1024)         9438208   ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 1024)         4096      ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 1024)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 512)          524800    ['activation_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 512)          2048      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 16, 16, 512)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 512)          262656    ['activation_10[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 512)          2359808   ['conv2d_12[0][0]']
#  anspose)
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 512)          1049088   ['activation_7[0][0]']
#
#  add (Add)                   (None, 16, 16, 512)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_11[0][0]']
#
#  activation_11 (Activation)  (None, 16, 16, 512)          0         ['add[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 1)            513       ['activation_11[0][0]']
#
#  activation_12 (Activation)  (None, 16, 16, 1)            0         ['conv2d_13[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 1)            0         ['activation_12[0][0]']
#  D)
#
#  multiply (Multiply)         (None, 32, 32, 512)          0         ['up_sampling2d[0][0]',
#                                                                      'activation_7[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 512)          262656    ['multiply[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 32, 32, 1024)         0         ['activation_9[0][0]']
#  g2D)
#
#  batch_normalization_11 (Ba  (None, 32, 32, 512)          2048      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  concatenate (Concatenate)   (None, 32, 32, 1536)         0         ['up_sampling2d_1[0][0]',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 512)          7078400   ['concatenate[0][0]']
#
#  batch_normalization_12 (Ba  (None, 32, 32, 512)          2048      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 512)          2359808   ['activation_13[0][0]']
#
#  batch_normalization_13 (Ba  (None, 32, 32, 512)          2048      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 32, 32, 512)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 256)          131328    ['activation_14[0][0]']
#
#  batch_normalization_14 (Ba  (None, 32, 32, 256)          1024      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 256)          65792     ['activation_15[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 256)          590080    ['conv2d_19[0][0]']
#  Transpose)
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 256)          262400    ['activation_5[0][0]']
#
#  add_1 (Add)                 (None, 32, 32, 256)          0         ['conv2d_transpose_1[0][0]',
#                                                                      'conv2d_18[0][0]']
#
#  activation_16 (Activation)  (None, 32, 32, 256)          0         ['add_1[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 1)            257       ['activation_16[0][0]']
#
#  activation_17 (Activation)  (None, 32, 32, 1)            0         ['conv2d_20[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 64, 64, 1)            0         ['activation_17[0][0]']
#  g2D)
#
#  multiply_1 (Multiply)       (None, 64, 64, 256)          0         ['up_sampling2d_2[0][0]',
#                                                                      'activation_5[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 256)          65792     ['multiply_1[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 64, 64, 512)          0         ['activation_14[0][0]']
#  g2D)
#
#  batch_normalization_15 (Ba  (None, 64, 64, 256)          1024      ['conv2d_21[0][0]']
#  tchNormalization)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 768)          0         ['up_sampling2d_3[0][0]',
#  )                                                                   'batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 256)          1769728   ['concatenate_1[0][0]']
#
#  batch_normalization_16 (Ba  (None, 64, 64, 256)          1024      ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 256)          590080    ['activation_18[0][0]']
#
#  batch_normalization_17 (Ba  (None, 64, 64, 256)          1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 64, 64, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 128)          32896     ['activation_19[0][0]']
#
#  batch_normalization_18 (Ba  (None, 64, 64, 128)          512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 128)          16512     ['activation_20[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 128)          147584    ['conv2d_26[0][0]']
#  Transpose)
#
#  conv2d_25 (Conv2D)          (None, 64, 64, 128)          65664     ['activation_3[0][0]']
#
#  add_2 (Add)                 (None, 64, 64, 128)          0         ['conv2d_transpose_2[0][0]',
#                                                                      'conv2d_25[0][0]']
#
#  activation_21 (Activation)  (None, 64, 64, 128)          0         ['add_2[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 1)            129       ['activation_21[0][0]']
#
#  activation_22 (Activation)  (None, 64, 64, 1)            0         ['conv2d_27[0][0]']
#
#  up_sampling2d_4 (UpSamplin  (None, 128, 128, 1)          0         ['activation_22[0][0]']
#  g2D)
#
#  multiply_2 (Multiply)       (None, 128, 128, 128)        0         ['up_sampling2d_4[0][0]',
#                                                                      'activation_3[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 128, 128, 128)        16512     ['multiply_2[0][0]']
#
#  up_sampling2d_5 (UpSamplin  (None, 128, 128, 256)        0         ['activation_19[0][0]']
#  g2D)
#
#  batch_normalization_19 (Ba  (None, 128, 128, 128)        512       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 384)        0         ['up_sampling2d_5[0][0]',
#  )                                                                   'batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 128, 128, 128)        442496    ['concatenate_2[0][0]']
#
#  batch_normalization_20 (Ba  (None, 128, 128, 128)        512       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 128, 128, 128)        147584    ['activation_23[0][0]']
#
#  batch_normalization_21 (Ba  (None, 128, 128, 128)        512       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 128, 128, 128)        0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 128, 128, 64)         8256      ['activation_24[0][0]']
#
#  batch_normalization_22 (Ba  (None, 128, 128, 64)         256       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 128, 128, 64)         4160      ['activation_25[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 128, 128, 64)         36928     ['conv2d_33[0][0]']
#  Transpose)
#
#  conv2d_32 (Conv2D)          (None, 128, 128, 64)         16448     ['activation_1[0][0]']
#
#  add_3 (Add)                 (None, 128, 128, 64)         0         ['conv2d_transpose_3[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  activation_26 (Activation)  (None, 128, 128, 64)         0         ['add_3[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 128, 128, 1)          65        ['activation_26[0][0]']
#
#  activation_27 (Activation)  (None, 128, 128, 1)          0         ['conv2d_34[0][0]']
#
#  up_sampling2d_6 (UpSamplin  (None, 256, 256, 1)          0         ['activation_27[0][0]']
#  g2D)
#
#  multiply_3 (Multiply)       (None, 256, 256, 64)         0         ['up_sampling2d_6[0][0]',
#                                                                      'activation_1[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 256, 256, 64)         4160      ['multiply_3[0][0]']
#
#  up_sampling2d_7 (UpSamplin  (None, 256, 256, 128)        0         ['activation_24[0][0]']
#  g2D)
#
#  batch_normalization_23 (Ba  (None, 256, 256, 64)         256       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 192)        0         ['up_sampling2d_7[0][0]',
#  )                                                                   'batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 256, 256, 64)         110656    ['concatenate_3[0][0]']
#
#  batch_normalization_24 (Ba  (None, 256, 256, 64)         256       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 256, 256, 64)         36928     ['activation_28[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 64)         256       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 256, 256, 1)          65        ['activation_29[0][0]']
#
#  batch_normalization_26 (Ba  (None, 256, 256, 1)          4         ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 256, 256, 1)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 37334665 (142.42 MB)
# Trainable params: 37319047 (142.36 MB)
# Non-trainable params: 15618 (61.01 KB)
# __________________________________________________________________________________________________

# %%
att_unet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2),
                   loss=tf.keras.losses.BinaryFocalCrossentropy(gamma=2),
                   metrics=['accuracy', jacard_coef_loss])

# %%
import datetime

start = datetime.datetime.now()

att_unet_model_hist = att_unet_model.fit(X_train, y_train, verbose=1, batch_size=BATCH_SIZE,
                                 validation_data=(X_test, y_test), shuffle=False,
                                 epochs=EPOCHS)
end = datetime.datetime.now()
att_unet_model.save('cancer_instance_seg_unet_50_epochs.hdf5')
print(f"U-Net training time: {end-start}")
# Out:
# Epoch 1/50
# 68/68 [==============================] - 109s 886ms/step - loss: 0.1325 - accuracy: 0.7975 - jacard_coef_loss: -0.0876 - val_loss: 1319.1046 - val_accuracy: 0.9194 - val_jacard_coef_loss: -2.8569e-05
# Epoch 2/50
# 68/68 [==============================] - 49s 720ms/step - loss: 0.0684 - accuracy: 0.9025 - jacard_coef_loss: -0.0957 - val_loss: 0.0906 - val_accuracy: 0.9075 - val_jacard_coef_loss: -0.1229
# Epoch 3/50
# 68/68 [==============================] - 48s 709ms/step - loss: 0.0532 - accuracy: 0.9168 - jacard_coef_loss: -0.1082 - val_loss: 0.0471 - val_accuracy: 0.9252 - val_jacard_coef_loss: -0.1242
# Epoch 4/50
# 68/68 [==============================] - 48s 713ms/step - loss: 0.0491 - accuracy: 0.9204 - jacard_coef_loss: -0.1135 - val_loss: 0.0555 - val_accuracy: 0.8956 - val_jacard_coef_loss: -0.1266
# Epoch 5/50
# 68/68 [==============================] - 48s 711ms/step - loss: 0.0459 - accuracy: 0.9256 - jacard_coef_loss: -0.1222 - val_loss: 0.0525 - val_accuracy: 0.9301 - val_jacard_coef_loss: -0.1265
# Epoch 6/50
# 68/68 [==============================] - 48s 712ms/step - loss: 0.0445 - accuracy: 0.9264 - jacard_coef_loss: -0.1270 - val_loss: 0.1497 - val_accuracy: 0.9194 - val_jacard_coef_loss: -0.0499
# Epoch 7/50
# 68/68 [==============================] - 48s 702ms/step - loss: 0.0434 - accuracy: 0.9297 - jacard_coef_loss: -0.1320 - val_loss: 0.0394 - val_accuracy: 0.9338 - val_jacard_coef_loss: -0.1669
# Epoch 8/50
# 68/68 [==============================] - 48s 713ms/step - loss: 0.0423 - accuracy: 0.9310 - jacard_coef_loss: -0.1372 - val_loss: 0.0467 - val_accuracy: 0.9226 - val_jacard_coef_loss: -0.1717
# Epoch 9/50
# 68/68 [==============================] - 47s 697ms/step - loss: 0.0414 - accuracy: 0.9328 - jacard_coef_loss: -0.1409 - val_loss: 0.0394 - val_accuracy: 0.9333 - val_jacard_coef_loss: -0.1835
# Epoch 10/50
# 68/68 [==============================] - 48s 711ms/step - loss: 0.0419 - accuracy: 0.9313 - jacard_coef_loss: -0.1411 - val_loss: 0.0437 - val_accuracy: 0.9322 - val_jacard_coef_loss: -0.1522
# Epoch 11/50
# 68/68 [==============================] - 48s 712ms/step - loss: 0.0412 - accuracy: 0.9330 - jacard_coef_loss: -0.1453 - val_loss: 0.0471 - val_accuracy: 0.9281 - val_jacard_coef_loss: -0.1319
# Epoch 12/50
# 68/68 [==============================] - 47s 699ms/step - loss: 0.0425 - accuracy: 0.9289 - jacard_coef_loss: -0.1411 - val_loss: 0.0529 - val_accuracy: 0.9238 - val_jacard_coef_loss: -0.1210
# Epoch 13/50
# 68/68 [==============================] - 48s 699ms/step - loss: 0.0419 - accuracy: 0.9308 - jacard_coef_loss: -0.1444 - val_loss: 0.1036 - val_accuracy: 0.9200 - val_jacard_coef_loss: -0.0851
# Epoch 14/50
# 68/68 [==============================] - 47s 699ms/step - loss: 0.0431 - accuracy: 0.9272 - jacard_coef_loss: -0.1417 - val_loss: 0.0518 - val_accuracy: 0.8981 - val_jacard_coef_loss: -0.1629
# Epoch 15/50
# 68/68 [==============================] - 48s 712ms/step - loss: 0.0408 - accuracy: 0.9319 - jacard_coef_loss: -0.1487 - val_loss: 0.0999 - val_accuracy: 0.8099 - val_jacard_coef_loss: -0.1207
# Epoch 16/50
# 68/68 [==============================] - 48s 711ms/step - loss: 0.0400 - accuracy: 0.9342 - jacard_coef_loss: -0.1527 - val_loss: 0.0522 - val_accuracy: 0.9043 - val_jacard_coef_loss: -0.1551
# Epoch 17/50
# 68/68 [==============================] - 49s 719ms/step - loss: 0.0395 - accuracy: 0.9345 - jacard_coef_loss: -0.1544 - val_loss: 0.0384 - val_accuracy: 0.9301 - val_jacard_coef_loss: -0.1734
# Epoch 18/50
# 68/68 [==============================] - 48s 712ms/step - loss: 0.0390 - accuracy: 0.9355 - jacard_coef_loss: -0.1574 - val_loss: 0.0340 - val_accuracy: 0.9414 - val_jacard_coef_loss: -0.1769
# Epoch 19/50
# 68/68 [==============================] - 48s 713ms/step - loss: 0.0385 - accuracy: 0.9362 - jacard_coef_loss: -0.1595 - val_loss: 0.0353 - val_accuracy: 0.9417 - val_jacard_coef_loss: -0.1729
# Epoch 20/50
# 68/68 [==============================] - 48s 703ms/step - loss: 0.0381 - accuracy: 0.9369 - jacard_coef_loss: -0.1614 - val_loss: 0.0353 - val_accuracy: 0.9396 - val_jacard_coef_loss: -0.1682
# Epoch 21/50
# 68/68 [==============================] - 49s 718ms/step - loss: 0.0378 - accuracy: 0.9373 - jacard_coef_loss: -0.1630 - val_loss: 0.0484 - val_accuracy: 0.9303 - val_jacard_coef_loss: -0.1629
# Epoch 22/50
# 68/68 [==============================] - 48s 702ms/step - loss: 0.0374 - accuracy: 0.9380 - jacard_coef_loss: -0.1653 - val_loss: 0.0555 - val_accuracy: 0.9269 - val_jacard_coef_loss: -0.1493
# Epoch 23/50
# 68/68 [==============================] - 49s 716ms/step - loss: 0.0371 - accuracy: 0.9387 - jacard_coef_loss: -0.1669 - val_loss: 0.0393 - val_accuracy: 0.9399 - val_jacard_coef_loss: -0.1825
# Epoch 24/50
# 68/68 [==============================] - 48s 701ms/step - loss: 0.0367 - accuracy: 0.9392 - jacard_coef_loss: -0.1691 - val_loss: 0.0526 - val_accuracy: 0.9317 - val_jacard_coef_loss: -0.1630
# Epoch 25/50
# 68/68 [==============================] - 48s 712ms/step - loss: 0.0362 - accuracy: 0.9403 - jacard_coef_loss: -0.1717 - val_loss: 0.0329 - val_accuracy: 0.9471 - val_jacard_coef_loss: -0.1861
# Epoch 26/50
# 68/68 [==============================] - 48s 713ms/step - loss: 0.0358 - accuracy: 0.9414 - jacard_coef_loss: -0.1737 - val_loss: 0.0410 - val_accuracy: 0.9368 - val_jacard_coef_loss: -0.1744
# Epoch 27/50
# 68/68 [==============================] - 47s 699ms/step - loss: 0.0363 - accuracy: 0.9407 - jacard_coef_loss: -0.1726 - val_loss: 0.0389 - val_accuracy: 0.9372 - val_jacard_coef_loss: -0.1757
# Epoch 28/50
# 68/68 [==============================] - 48s 711ms/step - loss: 0.0356 - accuracy: 0.9409 - jacard_coef_loss: -0.1758 - val_loss: 0.1306 - val_accuracy: 0.9193 - val_jacard_coef_loss: -0.0642
# Epoch 29/50
# 68/68 [==============================] - 48s 712ms/step - loss: 0.0349 - accuracy: 0.9425 - jacard_coef_loss: -0.1791 - val_loss: 0.1248 - val_accuracy: 0.9198 - val_jacard_coef_loss: -0.0839
# Epoch 30/50
# 68/68 [==============================] - 48s 713ms/step - loss: 0.0340 - accuracy: 0.9440 - jacard_coef_loss: -0.1819 - val_loss: 0.0655 - val_accuracy: 0.9337 - val_jacard_coef_loss: -0.1704
# Epoch 31/50
# 68/68 [==============================] - 47s 699ms/step - loss: 0.0336 - accuracy: 0.9443 - jacard_coef_loss: -0.1859 - val_loss: 0.0777 - val_accuracy: 0.9285 - val_jacard_coef_loss: -0.1517
# Epoch 32/50
# 68/68 [==============================] - 48s 699ms/step - loss: 0.0335 - accuracy: 0.9456 - jacard_coef_loss: -0.1860 - val_loss: 0.0342 - val_accuracy: 0.9428 - val_jacard_coef_loss: -0.1913
# Epoch 33/50
# 68/68 [==============================] - 48s 712ms/step - loss: 0.0337 - accuracy: 0.9443 - jacard_coef_loss: -0.1869 - val_loss: 0.0746 - val_accuracy: 0.9208 - val_jacard_coef_loss: -0.1232
# Epoch 34/50
# 68/68 [==============================] - 47s 699ms/step - loss: 0.0325 - accuracy: 0.9473 - jacard_coef_loss: -0.1923 - val_loss: 0.1412 - val_accuracy: 0.9194 - val_jacard_coef_loss: -0.0632
# Epoch 35/50
# 68/68 [==============================] - 47s 699ms/step - loss: 0.0312 - accuracy: 0.9499 - jacard_coef_loss: -0.1964 - val_loss: 0.1261 - val_accuracy: 0.9208 - val_jacard_coef_loss: -0.0771
# Epoch 36/50
# 68/68 [==============================] - 48s 708ms/step - loss: 0.0305 - accuracy: 0.9504 - jacard_coef_loss: -0.2012 - val_loss: 0.0720 - val_accuracy: 0.9336 - val_jacard_coef_loss: -0.1573
# Epoch 37/50
# 68/68 [==============================] - 47s 697ms/step - loss: 0.0311 - accuracy: 0.9500 - jacard_coef_loss: -0.2020 - val_loss: 0.0529 - val_accuracy: 0.9335 - val_jacard_coef_loss: -0.1840
# Epoch 38/50
# 68/68 [==============================] - 48s 712ms/step - loss: 0.0301 - accuracy: 0.9522 - jacard_coef_loss: -0.2049 - val_loss: 0.0639 - val_accuracy: 0.9277 - val_jacard_coef_loss: -0.1554
# Epoch 39/50
# 68/68 [==============================] - 48s 711ms/step - loss: 0.0290 - accuracy: 0.9537 - jacard_coef_loss: -0.2106 - val_loss: 0.0683 - val_accuracy: 0.9266 - val_jacard_coef_loss: -0.1473
# Epoch 40/50
# 68/68 [==============================] - 48s 710ms/step - loss: 0.0292 - accuracy: 0.9534 - jacard_coef_loss: -0.2095 - val_loss: 0.1197 - val_accuracy: 0.9218 - val_jacard_coef_loss: -0.1072
# Epoch 41/50
# 68/68 [==============================] - 47s 697ms/step - loss: 0.0295 - accuracy: 0.9529 - jacard_coef_loss: -0.2110 - val_loss: 0.0569 - val_accuracy: 0.9303 - val_jacard_coef_loss: -0.1623
# Epoch 42/50
# 68/68 [==============================] - 48s 699ms/step - loss: 0.0330 - accuracy: 0.9451 - jacard_coef_loss: -0.2024 - val_loss: 0.1130 - val_accuracy: 0.9206 - val_jacard_coef_loss: -0.0996
# Epoch 43/50
# 68/68 [==============================] - 48s 712ms/step - loss: 0.0268 - accuracy: 0.9572 - jacard_coef_loss: -0.2245 - val_loss: 0.0670 - val_accuracy: 0.9316 - val_jacard_coef_loss: -0.1482
# Epoch 44/50
# 68/68 [==============================] - 47s 697ms/step - loss: 0.0261 - accuracy: 0.9576 - jacard_coef_loss: -0.2314 - val_loss: 0.0504 - val_accuracy: 0.9333 - val_jacard_coef_loss: -0.1544
# Epoch 45/50
# 68/68 [==============================] - 48s 710ms/step - loss: 0.0235 - accuracy: 0.9630 - jacard_coef_loss: -0.2439 - val_loss: 0.0566 - val_accuracy: 0.9354 - val_jacard_coef_loss: -0.1686
# Epoch 46/50
# 68/68 [==============================] - 48s 711ms/step - loss: 0.0236 - accuracy: 0.9627 - jacard_coef_loss: -0.2482 - val_loss: 0.0675 - val_accuracy: 0.9283 - val_jacard_coef_loss: -0.1364
# Epoch 47/50
# 68/68 [==============================] - 48s 699ms/step - loss: 0.0227 - accuracy: 0.9645 - jacard_coef_loss: -0.2521 - val_loss: 0.0757 - val_accuracy: 0.9288 - val_jacard_coef_loss: -0.1319
# Epoch 48/50
# 68/68 [==============================] - 48s 710ms/step - loss: 0.0213 - accuracy: 0.9665 - jacard_coef_loss: -0.2573 - val_loss: 0.0697 - val_accuracy: 0.9346 - val_jacard_coef_loss: -0.1547
# Epoch 49/50
# 68/68 [==============================] - 47s 695ms/step - loss: 0.0203 - accuracy: 0.9684 - jacard_coef_loss: -0.2667 - val_loss: 0.1287 - val_accuracy: 0.9254 - val_jacard_coef_loss: -0.0967
# Epoch 50/50
# 68/68 [==============================] - 48s 711ms/step - loss: 0.0214 - accuracy: 0.9667 - jacard_coef_loss: -0.2711 - val_loss: 0.0589 - val_accuracy: 0.9439 - val_jacard_coef_loss: -0.1887
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# U-Net training time: 0:41:04.796115

# %%
att_unet_model.save('cancer_instance_seg_att_unet_50_epochs.hdf5')

# %%
import pandas as pd

att_unet_model_hist_df = pd.DataFrame(att_unet_model_hist.history)

with open('att_unet_model_hist_df.csv', mode='w') as f:
    att_unet_model_hist_df.to_csv(f)

# %% [markdown]
# ### Plot the training and validation accuracy and loss at each epoch

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(1, len(loss) + 1)
  plt.plot(epochs, loss, 'y', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()

# %%
plot_loss_curves(att_unet_model_hist)

# %%
def plot_jacard_curves(history):
  loss = history.history['loss']
  epochs = range(1, len(loss) + 1)
  acc = history.history['jacard_coef_loss']
  #acc = history.history['accuracy']
  val_acc = history.history['val_jacard_coef_loss']
  #val_acc = history.history['val_accuracy']

  plt.plot(epochs, acc, 'y', label='Training Jacard')
  plt.plot(epochs, val_acc, 'r', label='Validation Jacard')
  plt.title('Training and validation Jacard')
  plt.xlabel('Epochs')
  plt.ylabel('Jacard')
  plt.legend()
  plt.show()

# %%
def plot_loss_curves(history):
  fig = plt.figure(figsize=(10,10))

  loss = history.history['loss']
  val_loss = history.history['val_loss']
  acc = history.history['jacard_coef_loss']
  val_acc = history.history['val_jacard_coef_loss']
  epochs = range(1, len(loss) + 1)

  plt.subplot(2, 1, 1)
  plt.plot(epochs, loss, 'y', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()

  plt.subplot(2, 1, 2)
  plt.plot(epochs, acc, 'y', label='Training Jacard')
  plt.plot(epochs, val_acc, 'r', label='Validation Jacard')
  plt.title('Training and validation Jacard')
  plt.xlabel('Epochs')
  plt.ylabel('Jacard')
  plt.legend()


  plt.show()

# %%
plot_jacard_curves(att_unet_model_hist)

# %%
MODEL_PATH = '/content/cancer_instance_seg_att_unet_50_epochs.hdf5'

# %%
# Load the model for testing
model = tf.keras.models.load_model(MODEL_PATH, compile=False)

# %%
TEST_IMG_IX = 2

# %%
test_img = X_test[TEST_IMG_IX]
ground_truth_mask = y_test[TEST_IMG_IX]

test_img_input=np.expand_dims(test_img, 0)
prediction_mask = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth_mask[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction_mask, cmap='gray')

plt.show()

# %% [markdown]
# ### IoU (Intersection over Union) Calculation for single test image

# %%
from tensorflow.keras.metrics import MeanIoU

n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(ground_truth_mask[:,:,0], prediction_mask)

print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 1.0

# %% [markdown]
# ### Calculate IoU for all test images and calculate Avg. IoU

# %%
import pandas as pd

def calculate_IoU_of_test_dataset(model, X_test, y_test, n_classes=2):
  IoU_values = []

  for ix, test_img in enumerate(X_test):
    ground_truth = y_test[ix]
    temp_img_input = np.expand_dims(test_img, 0)

    prediction = (model.predict(temp_img_input)[0,:,:,0] > 0.5).astype(np.uint8)

    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)
    #print(IoU)

  df = pd.DataFrame(IoU_values, columns=["IoU"])
  #df = df[df.IoU != 1.0]
  mean_IoU = df.mean().values
  print("Mean IoU is: ", str(mean_IoU))

# %%
calculate_IoU_of_test_dataset(att_unet_model, X_test, y_test)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Mean IoU is:  [0.64373136]

# %% [markdown]
# ### Reference
#
# Original Paper: [Attention U-Net: Learning Where to Look for the Pancreas](https://arxiv.org/pdf/1804.03999.pdf)
#
# https://github.com/bnsreenu/python_for_microscopists
#
# https://github.com/bnsreenu/python_for_microscopists/blob/master/224_225_226_models.py
#
# [224 - Recurrent and Residual U-net](https://www.youtube.com/watch?v=7aDOtKN2cJs) by DigitalSreeni
#
# [225 - Attention U-net. What is attention and why is it needed for U-Net? ](https://www.youtube.com/watch?v=KOF38xAvo8I) by DigitalSreeni
#
# [226 - U-Net vs Attention U-Net vs Attention Residual U-Net - should you care? ](https://www.youtube.com/watch?v=L5iV5BHkMzM) by DigitalSreeni
