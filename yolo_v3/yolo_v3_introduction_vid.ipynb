# %% [markdown]
# ## YOLO (You Only Look Once)
#
# YOLOv3 has 53 convolutional layers called **Darknet-53** as you can see in the following figure.
#
# ![Darknet-53 Architecture](https://machinelearningspace.com/wp-content/uploads/2020/01/yolo_structure2.png)
#
#
# The YOLOv3 network divides an input image into **S x S** grid of cells and predicts bounding boxes as well as class probabilities for each grid. Each grid cell is responsible for predicting **B** bounding boxes and **C** class probabilities of objects whose centers fall inside the grid cell. Bounding boxes are the regions of interest **(ROI)** of the candidate objects.
#
# * The “**B**” is associated with the number of **using anchors**. Each bounding box has **(5 + C)** attributes. The value of “5” is related to **5 bounding box attributes**, those are **center coordinates (bx, by)** and **shape (bh, bw)** of the bounding box, and one **confidence score**.
#
# * The “**C**” is the number of **classes**. The **confidence score** reflects how confidence a box contains an object. The confidence score is in the range of **0 - 1**. (**Non-Maximum Suppression** (**NMS**)).
#
# Since we have S x S grid of cells, after running a single forward pass convolutional neural network to the whole image, YOLOv3 produces a **3-D tensor** with the shape of **S, S, (B x (5 + C))**.
#
# The following figure illustrates the basic principle of YOLOv3 where the input image is divided into the **13 x 13** grid of cells.
#
# ![Illustration](https://machinelearningspace.com/wp-content/uploads/2020/01/bbox_ok-2.png)
#
# YOLOv3 was trained on the **COCO** dataset with **C=80** and **B=3**. So, for the first prediction scale, after a single forward pass of CNN, the YOLOv3 outputs a tensor with the shape of **[(13, 13, 3 * (5 + 80)]**.

# %% [markdown]
# ### Anchor Box Algorithm
#
# One grid cell can detect only one object whose mid-point of the object falls inside the cell but in some cases grid cell contains more than one mid-point of the objects (object overlapping). In order to overcome this condition, YOLOv3 uses 3 different anchor boxes for every detection scale.
#
# Anchors are a set of **predefined bounding box shapes** that are used to predict the location and size of objects within an image. They calculated on the COCO dataset using K-Means clustering. Anchors provide a priori information about the expected sizes and aspect ratios of objects in the image. They act as **reference templates** for the network to make predictions. The anchor boxes are defined based on the dataset being used for training. Typically, the anchor boxes are chosen to represent **different object sizes** and **aspect ratios** commonly found in the dataset.
#
# During **training**, the network **adjusts the anchor boxes** to better fit the objects in the training images. The network **predicts offsets** from the anchor boxes to adjust their positions and sizes to match the **ground truth bounding boxes**.
#
# The use of anchors in YOLO helps in handling objects of various sizes and shapes by providing a set of predefined reference boxes. This allows the algorithm to efficiently detect and classify objects in real-time, making it popular for object detection tasks.
#
# While there are 3 predictions across scale, so the total anchor boxes are 9, they are: (10x13), (16x30), (33x23) for the first scale, (30x61), (62x45), (59x119) for the second scale, and (116x90), (156x198), (373x326) for the third scale.
#
# * by = σ(ty)+cy
#
# * bw = pwetw
#
# * bh = pheth
#
# Where **bx** and **by** are the **center coordinates** of the box, **bw** and **bh** are the **width** and **height** of the box, **cx** and **cy** are the location of filter application and ti are predicted during regression.
#
# https://www.youtube.com/watch?v=RTlwl2bv0Tg

# %% [markdown]
# ### Prediciton Across Scale
#
# YOLOv3 makes detection in 3 different scales in order to accommodate different objects size by using **strides** of **32**, **16** and **8**. This means, if we feed an input image of size **416 x 416**, YOLOv3 will make detection on the scale of **13 x 13**, **26 x 26**, and **52 x 52**.
#
# For the first scale, YOLOv3 **downsamples** the input image into 13 x 13 and makes a prediction at the **82nd layer**. The 1st detection scale yields a 3-D tensor of size **13 x 13 x 255**. After that, YOLOv3 takes the feature map from **layer 79** and applies one convolutional layer before **upsampling** it by a **factor of 2** to have a size of **26 x 26**. This upsampled feature map is then **concatenated** with the feature map from **layer 61**. The concatenated feature map is then subjected to a few more convolutional layers until the **2nd detection scale** is performed at layer **94**. The second prediction scale produces a 3-D tensor of size **26 x 26 x 255**. The same design is again performed one more time to predict the 3rd scale. The feature map from layer 91 is added one convolutional layer and is then concatenated with a feature map from layer 36. The final prediction layer is done at layer 106 yielding a 3-D tensor of size 52 x 52 x 255.
#
# ![yolo_v3.PNG](data:image/png;base64,...)
#
# https://towardsdatascience.com/yolo-v3-object-detection-53fb7d3bfe6b
#
#
# Once again, YOLOv3 predicts over 3 different scales detection, so if we feed an image of size 416x 416, it produces 3 different output shape tensor, 13 x 13 x 255, 26 x 26 x 255, and 52 x 52 x 255.

# %% [markdown]
# ### Bounding Box Prediction
#
# For each bounding box, YOLO predicts 4 coordinates, tx, ty, tw, th. The tx and ty are the bounding box’s center coordinate relative to the grid cell whose center falls inside, and the tw and th are the bounding box’s shape, width and height, respectively.
#
# The final output of the bounding box predictions:
#
# ![bounding_box_predictions](https://machinelearningspace.com/wp-content/uploads/2019/12/yolo_eq1-300x246.png)
#
#
# The pw and ph are the anchor’s width and height, respectively.
#
# ![bounding_box_anchor](https://machinelearningspace.com/wp-content/uploads/2019/12/yolo-regression.png)
#
# The YOLO algorithm returns bounding boxes in the form of **(bx, by, bw, bh)**. The bx and by are the center coordinates of the boxes and bw and bh are the box shape **(width and height)**. Generally, to draw boxes, we use the **top-left coordinate (x1, y1)** and the box shape (width and height). To do this just simply convert them using this simple relation:
#
# ![](https://machinelearningspace.com/wp-content/uploads/2019/12/bbox_formula2.png)
#
# ![](https://machinelearningspace.com/wp-content/uploads/2019/12/bbox-1-300x189.png)

# %% [markdown]
# ### Total Class Prediction
#
# COCO dataset has 80 different classes. If we split an image into a 13 x 13 grid of cells and use 3 anchors box, the total output prediction is 13 x 13 x 3 or 169 x 3. However, YOLOv3 uses 3 different prediction scales which splits an image into (13 x 13), (26 x 26) and (52 x 52) grid of cells and with 3 anchors for each scale. So, the total output prediction will be ([(13 x 13) + (26 x 26) + (52 x 52)] x 3) = 10,647.
#
# ### Non-maximum Suppression
#
# The non-maximum suppression (NMS) method is used to decide a bounding box for a situation with multiple bounding boxes for the same object. Basically, what NMS does is to clean up these detections. The first step of NMS is to suppress all the predictions boxes where the **confidence score** is**under** a certain **threshold** value. Let’s say the confidence threshold is set to 0.5, so every bounding box where the confidence score is less than or equal to 0.5 will be discarded.
#
# As a second step of NMS,  the rest of the higher confidence scores are sorted from the highest to the lowest one, then highlight the bounding box with the **highest** score as the **proper bounding box**, and after that find all the other bounding boxes that have a **high IOU** (intersection over union) with this highlighted box. Let’s say we’ve set the IOU threshold to 0.5, so every bounding box that has IOU greater than 0.5 must be removed because it has a high IOU that corresponds to the same highlighted object. This method allows us to **output only one proper bounding box** for a detected object. Repeat this process for the remaining bounding boxes and always highlight the highest score as an appropriate bounding box. Do the same step until all bounding boxes are selected properly.
#
# * YOLO applies a single neural network to the whole image and predicts the bounding boxes and class probabilities as well. This makes YOLO a super-fast real-time object detection algorithm.
# * YOLO divides an image into SxS grid cells. Every cell is responsible for detecting an object whose center falls inside.
# * To overcome the overlapping objects whose centers fall in the same grid cell, YOLOv3 uses anchor boxes.
# * To facilitate the prediction across scale, YOLOv3 uses three different numbers of grid cell sizes (13×13), (26×26), and (52×52).
# * A Non-Max Suppression is used to eliminate the overlapping boxes and keep only the accurate one.

# %% [markdown]
# ### Batch Normalization
#
# It is a preprocessing step of features extracted from previous layers, before feeding it to the next layers of the network. We normalize the input layer by adjusting and scaling the activations. This allows each layer of a network to learn by itself a little bit more independently of other layers.
#
# Almost every convolutional layer in Yolo has **batch normalization** after it. It helps the model **train faster** and **reduces variance** between units.
#
# ![Batch_normalization](https://raw.githubusercontent.com/shahkaran76/yolo_v3-tensorflow-ipynb/7472f58be09ba36094eb0b94a5406e83bb2e5386//images/batch%20norm.png)

# %% [markdown]
# ### Leaky ReLU
#
# ![Leaky_Relu](https://raw.githubusercontent.com/shahkaran76/yolo_v3-tensorflow-ipynb/7472f58be09ba36094eb0b94a5406e83bb2e5386//images/prelu.jpg)
#
# Suppose if, for whatever reason, the output of a ReLU is consistently 0 (for example, if the ReLU has a large negative bias), then the gradient through it will consistently be 0. The error signal backpropagated from later layers gets multiplied by this 0, so no error signal ever passes to earlier layers. In situations like that the Leaky ReLU is used.

# %% [markdown]
# YOLOv3 has 2 important files: **yolov3.cfg** and **yolov3.weights**.
# * The file **yolov3.cfg** contains all information related to the YOLOv3 architecture and its parameters
# * The file **yolov3.weights** contains the convolutional neural network (CNN) parameters of the YOLOv3 pre-trained weights.

# %% [markdown]
# #### Creating a Project Directory and Files
#
# Create folder with name PROJECTS, create a directory named YOLOv3_TF2 in PROJECTS. This is the directory where we’ll be working. Now, under the YOLOv3_TF2 directory, let’s create 4 subdirectories, namely: img, cfg, data,and weights. And still under PROJECTS, now create 5 python files, they are:
#
# * yolov3.py
# * convert_weights.py
# * utils.py
# * image.py
# * video.py
#
#
# https://github.com/pjreddie/darknet/blob/master/cfg/yolov3.cfg
#
# https://github.com/pjreddie/darknet/blob/master/data/coco.names
#
# https://github.com/RahmadSadli/Deep-Learning/blob/master/YOLOv3_TF2/yolov3.py

# %% [markdown]
# #### Converting the Weight parameters from the file yolov3.weights into the TF2
#
# ![](https://machinelearningspace.com/wp-content/uploads/2020/01/weights.jpg)
#
# When we re-write these weights to TensorFlow’s format for a convolutional with a batch normalization layer, we need to switch the position of beta and gamma. So, they’re ordered like this: beta, gamma, means, variance, and conv weights. However, the weights’ order remains the same for the convolutional without a batch normalization layer.
#
# https://machinelearningspace.com/yolov3-tensorflow-2-part-3/

# %%
! python /content/drive/MyDrive/MASTER/Master_Thesis/YOLO/PROJECTS/convert_weights.py
# Out:
# 2023-07-21 12:12:11.330898: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-21 12:12:12.687078: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-21 12:12:14.921934: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 12:12:14.952861: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 12:12:14.953128: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 12:12:14.953842: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 12:12:14.954066: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 12:12:14.954253: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 12:12:16.006378: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 12:12:16.006667: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 12:12:16.006879: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 12:12:16.007016: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-07-21 12:12:16.007067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13664 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 416, 416, 3  0           []
#                                 )]
#
#  tf.math.truediv (TFOpLambda)   (None, 416, 416, 3)  0           ['input_1[0][0]']
#
#  conv_0 (Conv2D)                (None, 416, 416, 32  864         ['tf.math.truediv[0][0]']
#                                 )
#
#  bnorm_0 (BatchNormalization)   (None, 416, 416, 32  128         ['conv_0[0][0]']
#                                 )
#
#  leaky_0 (LeakyReLU)            (None, 416, 416, 32  0           ['bnorm_0[0][0]']
#                                 )
#
#  zero_padding2d (ZeroPadding2D)  (None, 417, 417, 32  0          ['leaky_0[0][0]']
#                                 )
#
#  conv_1 (Conv2D)                (None, 208, 208, 64  18432       ['zero_padding2d[0][0]']
#                                 )
#
#  bnorm_1 (BatchNormalization)   (None, 208, 208, 64  256         ['conv_1[0][0]']
#                                 )
#
#  leaky_1 (LeakyReLU)            (None, 208, 208, 64  0           ['bnorm_1[0][0]']
#                                 )
#
#  conv_2 (Conv2D)                (None, 208, 208, 32  2048        ['leaky_1[0][0]']
#                                 )
#
#  bnorm_2 (BatchNormalization)   (None, 208, 208, 32  128         ['conv_2[0][0]']
#                                 )
#
#  leaky_2 (LeakyReLU)            (None, 208, 208, 32  0           ['bnorm_2[0][0]']
#                                 )
#
#  conv_3 (Conv2D)                (None, 208, 208, 64  18432       ['leaky_2[0][0]']
#                                 )
#
#  bnorm_3 (BatchNormalization)   (None, 208, 208, 64  256         ['conv_3[0][0]']
#                                 )
#
#  leaky_3 (LeakyReLU)            (None, 208, 208, 64  0           ['bnorm_3[0][0]']
#                                 )
#
#  tf.__operators__.add (TFOpLamb  (None, 208, 208, 64  0          ['leaky_3[0][0]',
#  da)                            )                                 'leaky_1[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 209, 209, 64  0          ['tf.__operators__.add[0][0]']
#  D)                             )
#
#  conv_5 (Conv2D)                (None, 104, 104, 12  73728       ['zero_padding2d_1[0][0]']
#                                 8)
#
#  bnorm_5 (BatchNormalization)   (None, 104, 104, 12  512         ['conv_5[0][0]']
#                                 8)
#
#  leaky_5 (LeakyReLU)            (None, 104, 104, 12  0           ['bnorm_5[0][0]']
#                                 8)
#
#  conv_6 (Conv2D)                (None, 104, 104, 64  8192        ['leaky_5[0][0]']
#                                 )
#
#  bnorm_6 (BatchNormalization)   (None, 104, 104, 64  256         ['conv_6[0][0]']
#                                 )
#
#  leaky_6 (LeakyReLU)            (None, 104, 104, 64  0           ['bnorm_6[0][0]']
#                                 )
#
#  conv_7 (Conv2D)                (None, 104, 104, 12  73728       ['leaky_6[0][0]']
#                                 8)
#
#  bnorm_7 (BatchNormalization)   (None, 104, 104, 12  512         ['conv_7[0][0]']
#                                 8)
#
#  leaky_7 (LeakyReLU)            (None, 104, 104, 12  0           ['bnorm_7[0][0]']
#                                 8)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 104, 104, 12  0          ['leaky_7[0][0]',
#  mbda)                          8)                                'leaky_5[0][0]']
#
#  conv_9 (Conv2D)                (None, 104, 104, 64  8192        ['tf.__operators__.add_1[0][0]']
#                                 )
#
#  bnorm_9 (BatchNormalization)   (None, 104, 104, 64  256         ['conv_9[0][0]']
#                                 )
#
#  leaky_9 (LeakyReLU)            (None, 104, 104, 64  0           ['bnorm_9[0][0]']
#                                 )
#
#  conv_10 (Conv2D)               (None, 104, 104, 12  73728       ['leaky_9[0][0]']
#                                 8)
#
#  bnorm_10 (BatchNormalization)  (None, 104, 104, 12  512         ['conv_10[0][0]']
#                                 8)
#
#  leaky_10 (LeakyReLU)           (None, 104, 104, 12  0           ['bnorm_10[0][0]']
#                                 8)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 104, 104, 12  0          ['leaky_10[0][0]',
#  mbda)                          8)                                'tf.__operators__.add_1[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, 105, 105, 12  0          ['tf.__operators__.add_2[0][0]']
#  D)                             8)
#
#  conv_12 (Conv2D)               (None, 52, 52, 256)  294912      ['zero_padding2d_2[0][0]']
#
#  bnorm_12 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_12[0][0]']
#
#  leaky_12 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_12[0][0]']
#
#  conv_13 (Conv2D)               (None, 52, 52, 128)  32768       ['leaky_12[0][0]']
#
#  bnorm_13 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_13[0][0]']
#
#  leaky_13 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_13[0][0]']
#
#  conv_14 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_13[0][0]']
#
#  bnorm_14 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_14[0][0]']
#
#  leaky_14 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_14[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_14[0][0]',
#  mbda)                                                            'leaky_12[0][0]']
#
#  conv_16 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_3[0][0]']
#
#  bnorm_16 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_16[0][0]']
#
#  leaky_16 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_16[0][0]']
#
#  conv_17 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_16[0][0]']
#
#  bnorm_17 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_17[0][0]']
#
#  leaky_17 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_17[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_17[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  conv_19 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_4[0][0]']
#
#  bnorm_19 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_19[0][0]']
#
#  leaky_19 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_19[0][0]']
#
#  conv_20 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_19[0][0]']
#
#  bnorm_20 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_20[0][0]']
#
#  leaky_20 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_20[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_20[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  conv_22 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_5[0][0]']
#
#  bnorm_22 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_22[0][0]']
#
#  leaky_22 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_22[0][0]']
#
#  conv_23 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_22[0][0]']
#
#  bnorm_23 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_23[0][0]']
#
#  leaky_23 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_23[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_23[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  conv_25 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_6[0][0]']
#
#  bnorm_25 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_25[0][0]']
#
#  leaky_25 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_25[0][0]']
#
#  conv_26 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_25[0][0]']
#
#  bnorm_26 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_26[0][0]']
#
#  leaky_26 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_26[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_26[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  conv_28 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_7[0][0]']
#
#  bnorm_28 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_28[0][0]']
#
#  leaky_28 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_28[0][0]']
#
#  conv_29 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_28[0][0]']
#
#  bnorm_29 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_29[0][0]']
#
#  leaky_29 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_29[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_29[0][0]',
#  mbda)                                                            'tf.__operators__.add_7[0][0]']
#
#  conv_31 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_8[0][0]']
#
#  bnorm_31 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_31[0][0]']
#
#  leaky_31 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_31[0][0]']
#
#  conv_32 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_31[0][0]']
#
#  bnorm_32 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_32[0][0]']
#
#  leaky_32 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_32[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_32[0][0]',
#  mbda)                                                            'tf.__operators__.add_8[0][0]']
#
#  conv_34 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_9[0][0]']
#
#  bnorm_34 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_34[0][0]']
#
#  leaky_34 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_34[0][0]']
#
#  conv_35 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_34[0][0]']
#
#  bnorm_35 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_35[0][0]']
#
#  leaky_35 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_35[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 52, 52, 256)  0          ['leaky_35[0][0]',
#  ambda)                                                           'tf.__operators__.add_9[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 53, 53, 256)  0          ['tf.__operators__.add_10[0][0]']
#  D)
#
#  conv_37 (Conv2D)               (None, 26, 26, 512)  1179648     ['zero_padding2d_3[0][0]']
#
#  bnorm_37 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_37[0][0]']
#
#  leaky_37 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_37[0][0]']
#
#  conv_38 (Conv2D)               (None, 26, 26, 256)  131072      ['leaky_37[0][0]']
#
#  bnorm_38 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_38[0][0]']
#
#  leaky_38 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_38[0][0]']
#
#  conv_39 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_38[0][0]']
#
#  bnorm_39 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_39[0][0]']
#
#  leaky_39 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_39[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 26, 26, 512)  0          ['leaky_39[0][0]',
#  ambda)                                                           'leaky_37[0][0]']
#
#  conv_41 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_11[0][0]']
#
#  bnorm_41 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_41[0][0]']
#
#  leaky_41 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_41[0][0]']
#
#  conv_42 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_41[0][0]']
#
#  bnorm_42 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_42[0][0]']
#
#  leaky_42 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_42[0][0]']
#
#  tf.__operators__.add_12 (TFOpL  (None, 26, 26, 512)  0          ['leaky_42[0][0]',
#  ambda)                                                           'tf.__operators__.add_11[0][0]']
#
#  conv_44 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_12[0][0]']
#
#  bnorm_44 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_44[0][0]']
#
#  leaky_44 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_44[0][0]']
#
#  conv_45 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_44[0][0]']
#
#  bnorm_45 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_45[0][0]']
#
#  leaky_45 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_45[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 26, 26, 512)  0          ['leaky_45[0][0]',
#  ambda)                                                           'tf.__operators__.add_12[0][0]']
#
#  conv_47 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_13[0][0]']
#
#  bnorm_47 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_47[0][0]']
#
#  leaky_47 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_47[0][0]']
#
#  conv_48 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_47[0][0]']
#
#  bnorm_48 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_48[0][0]']
#
#  leaky_48 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_48[0][0]']
#
#  tf.__operators__.add_14 (TFOpL  (None, 26, 26, 512)  0          ['leaky_48[0][0]',
#  ambda)                                                           'tf.__operators__.add_13[0][0]']
#
#  conv_50 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_14[0][0]']
#
#  bnorm_50 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_50[0][0]']
#
#  leaky_50 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_50[0][0]']
#
#  conv_51 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_50[0][0]']
#
#  bnorm_51 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_51[0][0]']
#
#  leaky_51 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_51[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 26, 26, 512)  0          ['leaky_51[0][0]',
#  ambda)                                                           'tf.__operators__.add_14[0][0]']
#
#  conv_53 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_15[0][0]']
#
#  bnorm_53 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_53[0][0]']
#
#  leaky_53 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_53[0][0]']
#
#  conv_54 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_53[0][0]']
#
#  bnorm_54 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_54[0][0]']
#
#  leaky_54 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_54[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 26, 26, 512)  0          ['leaky_54[0][0]',
#  ambda)                                                           'tf.__operators__.add_15[0][0]']
#
#  conv_56 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_16[0][0]']
#
#  bnorm_56 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_56[0][0]']
#
#  leaky_56 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_56[0][0]']
#
#  conv_57 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_56[0][0]']
#
#  bnorm_57 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_57[0][0]']
#
#  leaky_57 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_57[0][0]']
#
#  tf.__operators__.add_17 (TFOpL  (None, 26, 26, 512)  0          ['leaky_57[0][0]',
#  ambda)                                                           'tf.__operators__.add_16[0][0]']
#
#  conv_59 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_17[0][0]']
#
#  bnorm_59 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_59[0][0]']
#
#  leaky_59 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_59[0][0]']
#
#  conv_60 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_59[0][0]']
#
#  bnorm_60 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_60[0][0]']
#
#  leaky_60 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_60[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None, 26, 26, 512)  0          ['leaky_60[0][0]',
#  ambda)                                                           'tf.__operators__.add_17[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (None, 27, 27, 512)  0          ['tf.__operators__.add_18[0][0]']
#  D)
#
#  conv_62 (Conv2D)               (None, 13, 13, 1024  4718592     ['zero_padding2d_4[0][0]']
#                                 )
#
#  bnorm_62 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_62[0][0]']
#                                 )
#
#  leaky_62 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_62[0][0]']
#                                 )
#
#  conv_63 (Conv2D)               (None, 13, 13, 512)  524288      ['leaky_62[0][0]']
#
#  bnorm_63 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_63[0][0]']
#
#  leaky_63 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_63[0][0]']
#
#  conv_64 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_63[0][0]']
#                                 )
#
#  bnorm_64 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_64[0][0]']
#                                 )
#
#  leaky_64 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_64[0][0]']
#                                 )
#
#  tf.__operators__.add_19 (TFOpL  (None, 13, 13, 1024  0          ['leaky_64[0][0]',
#  ambda)                         )                                 'leaky_62[0][0]']
#
#  conv_66 (Conv2D)               (None, 13, 13, 512)  524288      ['tf.__operators__.add_19[0][0]']
#
#  bnorm_66 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_66[0][0]']
#
#  leaky_66 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_66[0][0]']
#
#  conv_67 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_66[0][0]']
#                                 )
#
#  bnorm_67 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_67[0][0]']
#                                 )
#
#  leaky_67 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_67[0][0]']
#                                 )
#
#  tf.__operators__.add_20 (TFOpL  (None, 13, 13, 1024  0          ['leaky_67[0][0]',
#  ambda)                         )                                 'tf.__operators__.add_19[0][0]']
#
#  conv_69 (Conv2D)               (None, 13, 13, 512)  524288      ['tf.__operators__.add_20[0][0]']
#
#  bnorm_69 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_69[0][0]']
#
#  leaky_69 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_69[0][0]']
#
#  conv_70 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_69[0][0]']
#                                 )
#
#  bnorm_70 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_70[0][0]']
#                                 )
#
#  leaky_70 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_70[0][0]']
#                                 )
#
#  tf.__operators__.add_21 (TFOpL  (None, 13, 13, 1024  0          ['leaky_70[0][0]',
#  ambda)                         )                                 'tf.__operators__.add_20[0][0]']
#
#  conv_72 (Conv2D)               (None, 13, 13, 512)  524288      ['tf.__operators__.add_21[0][0]']
#
#  bnorm_72 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_72[0][0]']
#
#  leaky_72 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_72[0][0]']
#
#  conv_73 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_72[0][0]']
#                                 )
#
#  bnorm_73 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_73[0][0]']
#                                 )
#
#  leaky_73 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_73[0][0]']
#                                 )
#
#  tf.__operators__.add_22 (TFOpL  (None, 13, 13, 1024  0          ['leaky_73[0][0]',
# ...
#  )
#
#  tf.math.multiply_4 (TFOpLambda  (None, 8112, 2)     0           ['tf.math.exp_2[0][0]']
#  )
#
#  tf.math.sigmoid_7 (TFOpLambda)  (None, 8112, 1)     0           ['tf.__operators__.getitem_10[0][
#                                                                  0]']
#
#  tf.math.sigmoid_8 (TFOpLambda)  (None, 8112, 80)    0           ['tf.__operators__.getitem_11[0][
#                                                                  0]']
#
#  tf.concat_3 (TFOpLambda)       (None, 2535, 85)     0           ['tf.concat[0][0]',
#                                                                   'tf.concat_2[0][0]']
#
#  tf.concat_5 (TFOpLambda)       (None, 8112, 85)     0           ['tf.math.multiply_5[0][0]',
#                                                                   'tf.math.multiply_4[0][0]',
#                                                                   'tf.math.sigmoid_7[0][0]',
#                                                                   'tf.math.sigmoid_8[0][0]']
#
#  tf.concat_6 (TFOpLambda)       (None, 10647, 85)    0           ['tf.concat_3[0][0]',
#                                                                   'tf.concat_5[0][0]']
#
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# layer:  1 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6654213f0>
# layer:  1 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6654220b0>
# layer:  2 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6653042b0>
# layer:  2 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6654231f0>
# layer:  3 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6653048e0>
# layer:  3 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa665307730>
# layer:  4 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa665305f90>
# layer:  4 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa665306ce0>
# layer:  6 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6646ba860>
# layer:  6 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6646bbd60>
# layer:  7 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6646d48b0>
# layer:  7 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6646d5f60>
# layer:  8 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6646d7550>
# layer:  8 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6646d7d30>
# layer:  10 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6646e9750>
# layer:  10 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6646eaef0>
# layer:  11 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6646eb400>
# layer:  11 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6646e8fa0>
# layer:  13 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa665422cb0>
# layer:  13 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa665421e10>
# layer:  14 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa66470d2a0>
# layer:  14 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66470e8c0>
# layer:  15 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa66470d210>
# layer:  15 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66470fa60>
# layer:  17 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664719420>
# layer:  17 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66470e710>
# layer:  18 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa66471b5e0>
# layer:  18 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6647189d0>
# layer:  20 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa66472c310>
# layer:  20 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66472dde0>
# layer:  21 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa66472fc40>
# layer:  21 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66472f580>
# layer:  23 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa66472d360>
# layer:  23 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664740c40>
# layer:  24 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6647433d0>
# layer:  24 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664742950>
# layer:  26 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa66475da50>
# layer:  26 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66475fe20>
# layer:  27 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa66475f580>
# layer:  27 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66475ded0>
# layer:  29 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664718f40>
# layer:  29 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6646b8070>
# layer:  30 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664775720>
# layer:  30 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6647769e0>
# layer:  32 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664777e50>
# layer:  32 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664777e80>
# layer:  33 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664780a90>
# layer:  33 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664783a30>
# layer:  35 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664782f80>
# layer:  35 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6647832b0>
# layer:  36 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664796800>
# layer:  36 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664797e20>
# layer:  38 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640adde0>
# layer:  38 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6640ad540>
# layer:  39 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640af970>
# layer:  39 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6640adf30>
# layer:  40 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640bd5d0>
# layer:  40 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6640bc1f0>
# layer:  42 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640bfd00>
# layer:  42 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6640d9630>
# layer:  43 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640bcf70>
# layer:  43 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6640bd390>
# layer:  45 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640be9b0>
# layer:  45 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66475f370>
# layer:  46 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664718a60>
# layer:  46 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6640db490>
# layer:  48 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640d8ca0>
# layer:  48 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664782350>
# layer:  49 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640eef50>
# layer:  49 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa665aa6da0>
# layer:  51 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640eef80>
# layer:  51 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6640ee680>
# layer:  52 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640eec50>
# layer:  52 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664102620>
# layer:  54 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664102e60>
# layer:  54 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664101840>
# layer:  55 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664100d90>
# layer:  55 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664119960>
# layer:  57 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664101a20>
# layer:  57 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66411a260>
# layer:  58 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa66411b160>
# layer:  58 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66411af50>
# layer:  60 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664101b70>
# layer:  60 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66411baf0>
# layer:  61 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa66411ba30>
# layer:  61 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa66470cbe0>
# layer:  63 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa665305600>
# layer:  63 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664780310>
# layer:  64 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6640d9f00>
# layer:  64 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664103b80>
# layer:  65 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664100850>
# layer:  65 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6641195a0>
# layer:  67 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6641401c0>
# layer:  67 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664143ca0>
# layer:  68 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664162d70>
# layer:  68 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664163f10>
# layer:  70 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664163130>
# layer:  70 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664163250>
# layer:  71 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6641761d0>
# layer:  71 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664177220>
# layer:  73 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6641762c0>
# layer:  73 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664163310>
# layer:  74 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664176ad0>
# layer:  74 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664196530>
# layer:  76 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664176620>
# layer:  76 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664196e30>
# layer:  77 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664194bb0>
# layer:  77 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664195210>
# layer:  78 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa6641940d0>
# layer:  78 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6647837c0>
# layer:  79 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664174d90>
# layer:  79 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664143d00>
# layer:  80 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa664196260>
# layer:  80 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa664174e20>
# layer:  81 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c033460>
# layer:  81 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c031de0>
# layer:  82 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c033040>
# layer:  85 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c030c40>
# layer:  85 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c0509a0>
# layer:  88 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa665ac26e0>
# layer:  88 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c07d180>
# layer:  89 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c07f670>
# layer:  89 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c07f190>
# layer:  90 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c07cd30>
# layer:  90 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6640ec220>
# layer:  91 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c033b20>
# layer:  91 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6641607f0>
# layer:  92 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c051300>
# layer:  92 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa6641606d0>
# layer:  93 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c0b3250>
# layer:  93 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c0b32e0>
# layer:  94 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c0b1960>
# layer:  97 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c07fe20>
# layer:  97 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c0c95a0>
# layer:  100 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c07c820>
# layer:  100 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c0efb80>
# layer:  101 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c0efd60>
# layer:  101 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c0ee8f0>
# layer:  102 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c10a8c0>
# layer:  102 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c10b3a0>
# layer:  103 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c10b490>
# layer:  103 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c109fc0>
# layer:  104 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c0ec550>
# layer:  104 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c1089a0>
# layer:  105 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c0b3910>
# layer:  105 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7aa65c033a30>
# layer:  106 <keras.layers.convolutional.conv2d.Conv2D object at 0x7aa65c0c94b0>
#
# The file 'yolov3_weights.tf' has been saved successfully.

# %% [markdown]
# Those created files are in the TensorFlow 2.0 weights format. So, anytime we want to use them, just simply call them like the only one file, yolov3_weights.tf

# %%
! python /content/drive/MyDrive/MASTER/Master_Thesis/YOLO/PROJECTS/video.py
# Out:
# 2023-07-26 08:05:30.442945: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-26 08:05:31.809122: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-26 08:05:35.702855: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-26 08:05:36.213375: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-26 08:05:36.213661: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-26 08:05:36.994223: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-26 08:05:36.994579: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-26 08:05:36.994793: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-26 08:05:39.470908: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-26 08:05:39.471264: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-26 08:05:39.471487: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-26 08:05:39.471650: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13664 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 416, 416, 3  0           []
#                                 )]
#
#  tf.math.truediv (TFOpLambda)   (None, 416, 416, 3)  0           ['input_1[0][0]']
#
#  conv_0 (Conv2D)                (None, 416, 416, 32  864         ['tf.math.truediv[0][0]']
#                                 )
#
#  bnorm_0 (BatchNormalization)   (None, 416, 416, 32  128         ['conv_0[0][0]']
#                                 )
#
#  leaky_0 (LeakyReLU)            (None, 416, 416, 32  0           ['bnorm_0[0][0]']
#                                 )
#
#  zero_padding2d (ZeroPadding2D)  (None, 417, 417, 32  0          ['leaky_0[0][0]']
#                                 )
#
#  conv_1 (Conv2D)                (None, 208, 208, 64  18432       ['zero_padding2d[0][0]']
#                                 )
#
#  bnorm_1 (BatchNormalization)   (None, 208, 208, 64  256         ['conv_1[0][0]']
#                                 )
#
#  leaky_1 (LeakyReLU)            (None, 208, 208, 64  0           ['bnorm_1[0][0]']
#                                 )
#
#  conv_2 (Conv2D)                (None, 208, 208, 32  2048        ['leaky_1[0][0]']
#                                 )
#
#  bnorm_2 (BatchNormalization)   (None, 208, 208, 32  128         ['conv_2[0][0]']
#                                 )
#
#  leaky_2 (LeakyReLU)            (None, 208, 208, 32  0           ['bnorm_2[0][0]']
#                                 )
#
#  conv_3 (Conv2D)                (None, 208, 208, 64  18432       ['leaky_2[0][0]']
#                                 )
#
#  bnorm_3 (BatchNormalization)   (None, 208, 208, 64  256         ['conv_3[0][0]']
#                                 )
#
#  leaky_3 (LeakyReLU)            (None, 208, 208, 64  0           ['bnorm_3[0][0]']
#                                 )
#
#  tf.__operators__.add (TFOpLamb  (None, 208, 208, 64  0          ['leaky_3[0][0]',
#  da)                            )                                 'leaky_1[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 209, 209, 64  0          ['tf.__operators__.add[0][0]']
#  D)                             )
#
#  conv_5 (Conv2D)                (None, 104, 104, 12  73728       ['zero_padding2d_1[0][0]']
#                                 8)
#
#  bnorm_5 (BatchNormalization)   (None, 104, 104, 12  512         ['conv_5[0][0]']
#                                 8)
#
#  leaky_5 (LeakyReLU)            (None, 104, 104, 12  0           ['bnorm_5[0][0]']
#                                 8)
#
#  conv_6 (Conv2D)                (None, 104, 104, 64  8192        ['leaky_5[0][0]']
#                                 )
#
#  bnorm_6 (BatchNormalization)   (None, 104, 104, 64  256         ['conv_6[0][0]']
#                                 )
#
#  leaky_6 (LeakyReLU)            (None, 104, 104, 64  0           ['bnorm_6[0][0]']
#                                 )
#
#  conv_7 (Conv2D)                (None, 104, 104, 12  73728       ['leaky_6[0][0]']
#                                 8)
#
#  bnorm_7 (BatchNormalization)   (None, 104, 104, 12  512         ['conv_7[0][0]']
#                                 8)
#
#  leaky_7 (LeakyReLU)            (None, 104, 104, 12  0           ['bnorm_7[0][0]']
#                                 8)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 104, 104, 12  0          ['leaky_7[0][0]',
#  mbda)                          8)                                'leaky_5[0][0]']
#
#  conv_9 (Conv2D)                (None, 104, 104, 64  8192        ['tf.__operators__.add_1[0][0]']
#                                 )
#
#  bnorm_9 (BatchNormalization)   (None, 104, 104, 64  256         ['conv_9[0][0]']
#                                 )
#
#  leaky_9 (LeakyReLU)            (None, 104, 104, 64  0           ['bnorm_9[0][0]']
#                                 )
#
#  conv_10 (Conv2D)               (None, 104, 104, 12  73728       ['leaky_9[0][0]']
#                                 8)
#
#  bnorm_10 (BatchNormalization)  (None, 104, 104, 12  512         ['conv_10[0][0]']
#                                 8)
#
#  leaky_10 (LeakyReLU)           (None, 104, 104, 12  0           ['bnorm_10[0][0]']
#                                 8)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 104, 104, 12  0          ['leaky_10[0][0]',
#  mbda)                          8)                                'tf.__operators__.add_1[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, 105, 105, 12  0          ['tf.__operators__.add_2[0][0]']
#  D)                             8)
#
#  conv_12 (Conv2D)               (None, 52, 52, 256)  294912      ['zero_padding2d_2[0][0]']
#
#  bnorm_12 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_12[0][0]']
#
#  leaky_12 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_12[0][0]']
#
#  conv_13 (Conv2D)               (None, 52, 52, 128)  32768       ['leaky_12[0][0]']
#
#  bnorm_13 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_13[0][0]']
#
#  leaky_13 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_13[0][0]']
#
#  conv_14 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_13[0][0]']
#
#  bnorm_14 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_14[0][0]']
#
#  leaky_14 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_14[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_14[0][0]',
#  mbda)                                                            'leaky_12[0][0]']
#
#  conv_16 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_3[0][0]']
#
#  bnorm_16 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_16[0][0]']
#
#  leaky_16 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_16[0][0]']
#
#  conv_17 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_16[0][0]']
#
#  bnorm_17 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_17[0][0]']
#
#  leaky_17 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_17[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_17[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  conv_19 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_4[0][0]']
#
#  bnorm_19 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_19[0][0]']
#
#  leaky_19 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_19[0][0]']
#
#  conv_20 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_19[0][0]']
#
#  bnorm_20 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_20[0][0]']
#
#  leaky_20 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_20[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_20[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  conv_22 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_5[0][0]']
#
#  bnorm_22 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_22[0][0]']
#
#  leaky_22 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_22[0][0]']
#
#  conv_23 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_22[0][0]']
#
#  bnorm_23 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_23[0][0]']
#
#  leaky_23 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_23[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_23[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  conv_25 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_6[0][0]']
#
#  bnorm_25 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_25[0][0]']
#
#  leaky_25 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_25[0][0]']
#
#  conv_26 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_25[0][0]']
#
#  bnorm_26 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_26[0][0]']
#
#  leaky_26 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_26[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_26[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  conv_28 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_7[0][0]']
#
#  bnorm_28 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_28[0][0]']
#
#  leaky_28 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_28[0][0]']
#
#  conv_29 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_28[0][0]']
#
#  bnorm_29 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_29[0][0]']
#
#  leaky_29 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_29[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_29[0][0]',
#  mbda)                                                            'tf.__operators__.add_7[0][0]']
#
#  conv_31 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_8[0][0]']
#
#  bnorm_31 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_31[0][0]']
#
#  leaky_31 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_31[0][0]']
#
#  conv_32 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_31[0][0]']
#
#  bnorm_32 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_32[0][0]']
#
#  leaky_32 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_32[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_32[0][0]',
#  mbda)                                                            'tf.__operators__.add_8[0][0]']
#
#  conv_34 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_9[0][0]']
#
#  bnorm_34 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_34[0][0]']
#
#  leaky_34 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_34[0][0]']
#
#  conv_35 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_34[0][0]']
#
#  bnorm_35 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_35[0][0]']
#
#  leaky_35 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_35[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 52, 52, 256)  0          ['leaky_35[0][0]',
#  ambda)                                                           'tf.__operators__.add_9[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 53, 53, 256)  0          ['tf.__operators__.add_10[0][0]']
#  D)
#
#  conv_37 (Conv2D)               (None, 26, 26, 512)  1179648     ['zero_padding2d_3[0][0]']
#
#  bnorm_37 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_37[0][0]']
#
#  leaky_37 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_37[0][0]']
#
#  conv_38 (Conv2D)               (None, 26, 26, 256)  131072      ['leaky_37[0][0]']
#
#  bnorm_38 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_38[0][0]']
#
#  leaky_38 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_38[0][0]']
#
#  conv_39 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_38[0][0]']
#
#  bnorm_39 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_39[0][0]']
#
#  leaky_39 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_39[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 26, 26, 512)  0          ['leaky_39[0][0]',
#  ambda)                                                           'leaky_37[0][0]']
#
#  conv_41 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_11[0][0]']
#
#  bnorm_41 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_41[0][0]']
#
#  leaky_41 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_41[0][0]']
#
#  conv_42 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_41[0][0]']
#
#  bnorm_42 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_42[0][0]']
#
#  leaky_42 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_42[0][0]']
#
#  tf.__operators__.add_12 (TFOpL  (None, 26, 26, 512)  0          ['leaky_42[0][0]',
#  ambda)                                                           'tf.__operators__.add_11[0][0]']
#
#  conv_44 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_12[0][0]']
#
#  bnorm_44 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_44[0][0]']
#
#  leaky_44 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_44[0][0]']
#
#  conv_45 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_44[0][0]']
#
#  bnorm_45 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_45[0][0]']
#
#  leaky_45 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_45[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 26, 26, 512)  0          ['leaky_45[0][0]',
#  ambda)                                                           'tf.__operators__.add_12[0][0]']
#
#  conv_47 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_13[0][0]']
#
#  bnorm_47 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_47[0][0]']
#
#  leaky_47 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_47[0][0]']
#
#  conv_48 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_47[0][0]']
#
#  bnorm_48 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_48[0][0]']
#
#  leaky_48 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_48[0][0]']
#
#  tf.__operators__.add_14 (TFOpL  (None, 26, 26, 512)  0          ['leaky_48[0][0]',
#  ambda)                                                           'tf.__operators__.add_13[0][0]']
#
#  conv_50 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_14[0][0]']
#
#  bnorm_50 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_50[0][0]']
#
#  leaky_50 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_50[0][0]']
#
#  conv_51 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_50[0][0]']
#
#  bnorm_51 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_51[0][0]']
#
#  leaky_51 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_51[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 26, 26, 512)  0          ['leaky_51[0][0]',
#  ambda)                                                           'tf.__operators__.add_14[0][0]']
#
#  conv_53 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_15[0][0]']
#
#  bnorm_53 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_53[0][0]']
#
#  leaky_53 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_53[0][0]']
#
#  conv_54 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_53[0][0]']
#
#  bnorm_54 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_54[0][0]']
#
#  leaky_54 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_54[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 26, 26, 512)  0          ['leaky_54[0][0]',
#  ambda)                                                           'tf.__operators__.add_15[0][0]']
#
#  conv_56 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_16[0][0]']
#
#  bnorm_56 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_56[0][0]']
#
#  leaky_56 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_56[0][0]']
#
#  conv_57 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_56[0][0]']
#
#  bnorm_57 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_57[0][0]']
#
#  leaky_57 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_57[0][0]']
#
#  tf.__operators__.add_17 (TFOpL  (None, 26, 26, 512)  0          ['leaky_57[0][0]',
#  ambda)                                                           'tf.__operators__.add_16[0][0]']
#
#  conv_59 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_17[0][0]']
#
#  bnorm_59 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_59[0][0]']
#
#  leaky_59 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_59[0][0]']
#
#  conv_60 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_59[0][0]']
#
#  bnorm_60 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_60[0][0]']
#
#  leaky_60 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_60[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None, 26, 26, 512)  0          ['leaky_60[0][0]',
#  ambda)                                                           'tf.__operators__.add_17[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (None, 27, 27, 512)  0          ['tf.__operators__.add_18[0][0]']
#  D)
#
#  conv_62 (Conv2D)               (None, 13, 13, 1024  4718592     ['zero_padding2d_4[0][0]']
#                                 )
#
#  bnorm_62 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_62[0][0]']
#                                 )
#
#  leaky_62 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_62[0][0]']
#                                 )
#
#  conv_63 (Conv2D)               (None, 13, 13, 512)  524288      ['leaky_62[0][0]']
#
#  bnorm_63 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_63[0][0]']
#
#  leaky_63 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_63[0][0]']
#
#  conv_64 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_63[0][0]']
#                                 )
#
#  bnorm_64 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_64[0][0]']
#                                 )
#
#  leaky_64 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_64[0][0]']
#                                 )
#
#  tf.__operators__.add_19 (TFOpL  (None, 13, 13, 1024  0          ['leaky_64[0][0]',
#  ambda)                         )                                 'leaky_62[0][0]']
#
#  conv_66 (Conv2D)               (None, 13, 13, 512)  524288      ['tf.__operators__.add_19[0][0]']
#
#  bnorm_66 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_66[0][0]']
#
#  leaky_66 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_66[0][0]']
#
#  conv_67 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_66[0][0]']
#                                 )
#
#  bnorm_67 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_67[0][0]']
#                                 )
#
#  leaky_67 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_67[0][0]']
#                                 )
#
#  tf.__operators__.add_20 (TFOpL  (None, 13, 13, 1024  0          ['leaky_67[0][0]',
#  ambda)                         )                                 'tf.__operators__.add_19[0][0]']
#
#  conv_69 (Conv2D)               (None, 13, 13, 512)  524288      ['tf.__operators__.add_20[0][0]']
#
#  bnorm_69 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_69[0][0]']
#
#  leaky_69 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_69[0][0]']
#
#  conv_70 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_69[0][0]']
#                                 )
#
#  bnorm_70 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_70[0][0]']
#                                 )
#
#  leaky_70 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_70[0][0]']
#                                 )
#
#  tf.__operators__.add_21 (TFOpL  (None, 13, 13, 1024  0          ['leaky_70[0][0]',
#  ambda)                         )                                 'tf.__operators__.add_20[0][0]']
#
#  conv_72 (Conv2D)               (None, 13, 13, 512)  524288      ['tf.__operators__.add_21[0][0]']
#
#  bnorm_72 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_72[0][0]']
#
#  leaky_72 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_72[0][0]']
#
#  conv_73 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_72[0][0]']
#                                 )
#
#  bnorm_73 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_73[0][0]']
#                                 )
#
#  leaky_73 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_73[0][0]']
#                                 )
#
#  tf.__operators__.add_22 (TFOpL  (None, 13, 13, 1024  0          ['leaky_73[0][0]',
#  ambda)                         )                                 'tf.__operators__.add_21[0][0]']
#
# ...
# Estimated frames per second : 7.219919612349058
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 6.680498150015211
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 6.656653314119208
# 1/1 [==============================] - 0s 27ms/step
# Estimated frames per second : 6.631226798712428
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.062068965517241
# 1/1 [==============================] - 0s 30ms/step
# Estimated frames per second : 7.150974535237394
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.9824884424386
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.916602766110773
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.139759279312848
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 8.020453159091387
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.790789554337469
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 8.205092892369269
# 1/1 [==============================] - 0s 29ms/step
# Estimated frames per second : 7.233454284571129
# 1/1 [==============================] - 0s 23ms/step
# Estimated frames per second : 7.645203684159681
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.171507391619455
# 1/1 [==============================] - 0s 23ms/step
# Estimated frames per second : 8.373368469385717
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.064971465917436
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.330775754710798
# 1/1 [==============================] - 0s 32ms/step
# Estimated frames per second : 7.577210040069227
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.850482798270027
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.90194323176441
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.795698365140848
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.819917789687288
# 1/1 [==============================] - 0s 28ms/step
# Estimated frames per second : 7.878639427158861
# 1/1 [==============================] - 0s 29ms/step
# Estimated frames per second : 7.981837592605632
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 6.960737910867855
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.85141423784654
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.338434055984309
# 1/1 [==============================] - 0s 33ms/step
# Estimated frames per second : 6.523094341618027
# 1/1 [==============================] - 0s 27ms/step
# Estimated frames per second : 7.444893322446661
# 1/1 [==============================] - 0s 27ms/step
# Estimated frames per second : 7.063662666347809
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.238197795219063
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.926493432864027
# 1/1 [==============================] - 0s 23ms/step
# Estimated frames per second : 7.628087660270983
# 1/1 [==============================] - 0s 23ms/step
# Estimated frames per second : 6.63562251518378
# 1/1 [==============================] - 0s 34ms/step
# Estimated frames per second : 7.017982066456845
# 1/1 [==============================] - 0s 27ms/step
# Estimated frames per second : 7.7735348301029354
# 1/1 [==============================] - 0s 23ms/step
# Estimated frames per second : 6.456689131565903
# 1/1 [==============================] - 0s 37ms/step
# Estimated frames per second : 7.0646382709228845
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.241209404948319
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.93396033685676
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.107050448945288
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.127866056894815
# 1/1 [==============================] - 0s 31ms/step
# Estimated frames per second : 6.814023459076584
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.81020019403049
# 1/1 [==============================] - 0s 23ms/step
# Estimated frames per second : 6.365953571672497
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.877204152041182
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.4056553635906175
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.214638388214395
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.00441222216073
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.284345263334537
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.135685799854135
# 1/1 [==============================] - 0s 37ms/step
# Estimated frames per second : 7.438410558443332
# 1/1 [==============================] - 0s 23ms/step
# Estimated frames per second : 8.139759279312848
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.641554362420998
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.108836908966827
# 1/1 [==============================] - 0s 31ms/step
# Estimated frames per second : 7.916604223015377
# 1/1 [==============================] - 0s 27ms/step
# Estimated frames per second : 7.910154400906754
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.615000136166813
# 1/1 [==============================] - 0s 23ms/step
# Estimated frames per second : 8.188961127706515
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.927452247838725
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.461368779085488
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.557753884465202
# 1/1 [==============================] - 0s 31ms/step
# Estimated frames per second : 7.693175690299671
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.451930183637501
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 6.93639125423157
# 1/1 [==============================] - 0s 32ms/step
# Estimated frames per second : 6.473850257144798
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.653506559431463
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.053624853060133
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.734658124859388
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.085535507041945
# 1/1 [==============================] - 0s 41ms/step
# Estimated frames per second : 5.341497395667512
# 1/1 [==============================] - 0s 40ms/step
# Estimated frames per second : 4.793687511714768
# 1/1 [==============================] - 0s 44ms/step
# Estimated frames per second : 4.792865843764355
# 1/1 [==============================] - 0s 39ms/step
# Estimated frames per second : 5.044899235622057
# 1/1 [==============================] - 0s 37ms/step
# Estimated frames per second : 5.792229529115099
# 1/1 [==============================] - 0s 65ms/step
# Estimated frames per second : 5.016611987087407
# 1/1 [==============================] - 0s 37ms/step
# Estimated frames per second : 5.565402002815672
# 1/1 [==============================] - 0s 38ms/step
# Estimated frames per second : 5.175188533975599
# 1/1 [==============================] - 0s 38ms/step
# Estimated frames per second : 5.301300329632551
# 1/1 [==============================] - 0s 38ms/step
# Estimated frames per second : 5.127222674519526
# 1/1 [==============================] - 0s 40ms/step
# Estimated frames per second : 5.4214349604214815
# 1/1 [==============================] - 0s 42ms/step
# Estimated frames per second : 5.469630363767955
# 1/1 [==============================] - 0s 53ms/step
# Estimated frames per second : 4.980092945498413
# 1/1 [==============================] - 0s 38ms/step
# Estimated frames per second : 5.717325074664707
# 1/1 [==============================] - 0s 37ms/step
# Estimated frames per second : 5.236308432916689
# 1/1 [==============================] - 0s 37ms/step
# Estimated frames per second : 5.6712968534291015
# 1/1 [==============================] - 0s 38ms/step
# Estimated frames per second : 5.769029954417788
# 1/1 [==============================] - 0s 37ms/step
# Estimated frames per second : 5.339776927062712
# 1/1 [==============================] - 0s 52ms/step
# Estimated frames per second : 4.526587185528058
# 1/1 [==============================] - 0s 36ms/step
# Estimated frames per second : 5.694233411350714
# 1/1 [==============================] - 0s 65ms/step
# Estimated frames per second : 4.892868641714923
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.404975486258357
# 1/1 [==============================] - 0s 36ms/step
# Estimated frames per second : 6.963950800945727
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 7.742668165615372
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 6.688146701215866
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.830073217265983
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.53757100779401
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.888033400409983
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.895339489479369
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.5330006323810235
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.992164664006616
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 7.377129741185989
# 1/1 [==============================] - 0s 28ms/step
# Estimated frames per second : 7.594964581130217
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.968538523210438
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 6.9301336523321
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.748060354382491
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.743940445770497
# 1/1 [==============================] - 0s 23ms/step
# Estimated frames per second : 7.374250365257385
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.429622098069572
# 1/1 [==============================] - 0s 30ms/step
# Estimated frames per second : 6.572640116838467
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.5135095434718355
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 7.824712284504872
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.135433315230042
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.421484649398309
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.858166073693539
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.097268287032568
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.162236532020932
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 6.621156487284323
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.989865759410843
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.122844764979403
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 8.100161257616284
# 1/1 [==============================] - 0s 27ms/step
# Estimated frames per second : 7.305953380456859
# 1/1 [==============================] - 0s 31ms/step
# Estimated frames per second : 7.49771456049309
# 1/1 [==============================] - 0s 28ms/step
# Estimated frames per second : 7.817609781555207
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 6.456063010548449
# 1/1 [==============================] - 0s 30ms/step
# Estimated frames per second : 7.308359397461253
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 7.123647641078422
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 6.9781321123873665
# 1/1 [==============================] - 0s 34ms/step
# Estimated frames per second : 7.325412308385539
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 7.377272471435808
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.843720429222754
# 1/1 [==============================] - 0s 27ms/step
# Estimated frames per second : 7.898371855662726
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.612742717681262
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.923932736468041
# 1/1 [==============================] - 0s 23ms/step
# Estimated frames per second : 8.0217723504155
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.124059026551078
# 1/1 [==============================] - 0s 38ms/step
# Estimated frames per second : 7.606976001857172
# 1/1 [==============================] - 0s 30ms/step
# Estimated frames per second : 7.915588275813913
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.163571001765337
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 6.840014938005646
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 8.189952511872033
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.268727981721009
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 7.2089003012943795
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.9121240645827005
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 7.7335314822633965
# 1/1 [==============================] - 0s 33ms/step
# Estimated frames per second : 6.852071972580629
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.39034919247698
# 1/1 [==============================] - 0s 30ms/step
# Estimated frames per second : 8.079704728808204
# 1/1 [==============================] - 0s 31ms/step
# Estimated frames per second : 7.581401065729635
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.712797276995133
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.406165353524295
# 1/1 [==============================] - 0s 30ms/step
# Estimated frames per second : 7.635767171493746
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 7.983204889311009
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 8.041304076917916
# 1/1 [==============================] - 0s 27ms/step
# Estimated frames per second : 8.294957925026452
# 1/1 [==============================] - 0s 24ms/step
# Estimated frames per second : 8.256698977141193
# 1/1 [==============================] - 0s 26ms/step
# Estimated frames per second : 7.254974676888163
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 8.547192611717811
# 1/1 [==============================] - 0s 25ms/step
# Estimated frames per second : 7.34147827121943
# Detections have been performed successfully.

# %% [markdown]
# #### Reference
#
# https://machinelearningspace.com/yolov3-tensorflow-2-part-1/
#
# https://machinelearningspace.com/yolov3-tensorflow-2-part-2/
#
# https://machinelearningspace.com/yolov3-tensorflow-2-part-3/
#
# https://github.com/shahkaran76/yolo_v3-tensorflow-ipynb/blob/master/YOLO%20Tensorflow.ipynb
#
# https://medium.com/analytics-vidhya/yolov3-object-detection-in-tensorflow-2-x-8a1a104c46a8
#
# https://medium.com/@shahkaran76/yolo-object-detection-algorithm-in-tensorflow-e080a58fa79b
#
# https://www.kaggle.com/code/aruchomu/yolo-v3-object-detection-in-tensorflow
#
# https://ecevit2804.medium.com/yolo-v5-algoritmas%C4%B1-ile-nesne-tespit-e%C4%9Fitimi-5c063fa0df70
#
# https://www.google.com/search?q=training+yolo+v8&rlz=1C1GCEB_enTR910TR910&oq=Training+YOLO+v&aqs=chrome.1.69i57j0i19i512l4j0i10i19i22i30j0i19i22i30l4.5694j0j7&sourceid=chrome&ie=UTF-8#fpstate=ive&vld=cid:0e57d5df,vid:iy34dSwfEsY
